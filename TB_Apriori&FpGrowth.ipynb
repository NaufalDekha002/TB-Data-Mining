# %% [markdown]
# <a href="https://colab.research.google.com/github/Syatiri/TB-Data-Mining/blob/main/TB_Apriori%26FpGrowth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install apyori
# !pip install pyfpgrowth
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ...

# %%
import numpy as np
import pandas as pd
import pyfpgrowth
from apyori import apriori
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df = pd.read_excel('tbmarket_dataset.xlsx')
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      BillNo                                  Itemname  Quantity     Price  \
# 0      1000           Apples, Potatoes, Cereal, Bread         5  8.030000
# 1      1000                     Butter, Eggs, Chicken         4  6.060000
# 2      1000                    Eggs, Onions, Tomatoes         4  0.129167
# 3      1000           Potatoes, Coffee, Cheese, Sugar         4  8.010000
# 4      1004                       Oranges, Juice, Tea         2  7.260000
# ..      ...                                       ...       ...       ...
# 495    1493                   Cereal, Potatoes, Pasta         2  4.240000
# ...

# %%
data=df.drop(['BillNo','Quantity','Price','CustomerID'],axis=1)
data.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                           Itemname
# 0  Apples, Potatoes, Cereal, Bread
# 1            Butter, Eggs, Chicken
# 2           Eggs, Onions, Tomatoes
# 3  Potatoes, Coffee, Cheese, Sugar
# 4              Oranges, Juice, Tea

# %%
#mengubah dataset ke bentuk data frame
records = []
for i in range(data.shape[0]):
    records.append([str(data.values[i,j]).split(',') for j in range(data.shape[1])])

trx = [[] for trx in range(len(records))]
for i in range(len(records)):
    for j in records[i][0]:
        trx[i].append(j)
trx
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [['Apples', ' Potatoes', ' Cereal', ' Bread'],
#  ['Butter', ' Eggs', ' Chicken'],
#  ['Eggs', ' Onions', ' Tomatoes'],
#  ['Potatoes', ' Coffee', ' Cheese', ' Sugar'],
#  ['Oranges', ' Juice', ' Tea'],
#  ['Milk', ' Coffe', ' Sugar', ' Yogurt'],
#  ['Onions', ' Tomatoes', ' Bananas', ' Pasta'],
#  ['Cereal', ' Potatoes', ' Pasta'],
#  ['Tomatoes', ' Bread', ' Chicken', ' Onions'],
#  ['Potatoes', ' Bread', ' Cereal'],
#  ['Cereal', ' Potatoes', ' Pasta', ' Bread'],
#  ['Bananas', ' Oranges', ' Sugar', ' Coffee', ' Tea'],
#  ['Tomatoes', ' Bread', ' Chicken', ' Onions', ' Pasta'],
#  ['Pasta', ' Onions', ' Milk'],
# ...

# %%
from mlxtend.frequent_patterns import apriori, association_rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
frequent_itemsets = apriori(trx_df, min_support=0.3, use_colnames=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
pd.set_option('max_colwidth', 1000)
Result = pd.DataFrame(columns=['Rule', 'Support', 'Confidence'])
for index, item in association_result.iterrows():
    antecedents = ', '.join(list(item['antecedents']))
    consequents = ', '.join(list(item['consequents']))
    rule = f"{antecedents} -> {consequents}"
    support = f"{item['support']*100:.2f}%"
    confidence = f"{item['confidence']*100:.2f}%"

    # Tambahkan baris baru ke DataFrame menggunakan .loc[]
    Result.loc[len(Result)] = {
        'Rule': rule,
        'Support': support,
        'Confidence': confidence,
    }

print(Result.tail(20))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                     Rule Support Confidence
# 6022  Pasta,  Cheese,  Milk ->  Onions,  Tissue,  Cereal   0.40%     33.33%
# 6023   Cheese,  Milk,  Cereal ->  Onions,  Tissue, Pasta   0.40%     33.33%
# 6024  Pasta,  Cheese,  Cereal ->  Onions,  Tissue,  Milk   0.40%     33.33%
# 6025  Pasta,  Milk,  Cereal ->  Onions,  Tissue,  Cheese   0.40%     33.33%
# 6026   Onions,  Tissue -> Pasta,  Cheese,  Milk,  Cereal   0.40%     50.00%
# 6027   Onions,  Cheese -> Pasta,  Tissue,  Milk,  Cereal   0.40%     33.33%
# 6028   Onions,  Milk -> Pasta,  Tissue,  Cheese,  Cereal   0.40%     15.38%
# ...

# %% [markdown]
# FP-GROWTH

# %%
FrequentPatterns=pyfpgrowth.find_frequent_patterns(trx,10)
FrequentPatterns
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {('Cheese',): 13,
#  (' Tomatoes', 'Cheese'): 13,
#  (' Potatoes', 'Cheese'): 13,
#  (' Potatoes', ' Tomatoes', 'Cheese'): 13,
#  ('Oranges',): 15,
#  ('Milk',): 15,
#  ('Yogurt',): 17,
#  (' Cheese',): 19,
#  (' Coffe',): 21,
#  ('Bread',): 21,
#  (' Eggs', 'Chicken'): 11,
#  (' Bread', 'Chicken'): 11,
#  ('Apples',): 23,
#  (' Soda', 'Apples'): 12,
#  (' Pasta', 'Eggs'): 10,
#  (' Chicken', 'Eggs'): 11,
#  (' Chicken', ' Onions', 'Eggs'): 11,
#  (' Butter', 'Eggs'): 14,
#  (' Butter', ' Onions', 'Eggs'): 14,
#  (' Onions', 'Eggs'): 20,
#  ('Coffee',): 24,
#  (' Tea', 'Coffee'): 11,
#  ('Juice',): 24,
#  (' Apples', 'Juice'): 10,
# ...

# %%
Rules = pyfpgrowth.generate_association_rules(FrequentPatterns,0.5)
Rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {('Cheese',): ((' Potatoes', ' Tomatoes'), 1.0),
#  (' Potatoes', ' Tomatoes'): (('Cheese',), 0.8125),
#  (' Potatoes', 'Cheese'): ((' Tomatoes',), 1.0),
#  (' Tomatoes', 'Cheese'): ((' Potatoes',), 1.0),
#  ('Apples',): ((' Soda',), 0.5217391304347826),
#  (' Chicken', ' Onions'): (('Eggs',), 0.5238095238095238),
#  (' Chicken', 'Eggs'): ((' Onions',), 1.0),
#  (' Onions', 'Eggs'): ((' Butter',), 0.7),
#  (' Butter', ' Onions'): (('Eggs',), 0.7777777777777778),
#  (' Butter', 'Eggs'): ((' Onions',), 1.0),
#  (' Chicken', 'Sugar'): ((' Eggs',), 0.7692307692307693),
#  (' Eggs', 'Sugar'): ((' Chicken',), 1.0),
# ...
